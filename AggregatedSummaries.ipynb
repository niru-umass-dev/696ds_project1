# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/pgeorge_umass_edu/.local/lib/python3.11/site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /modules/apps/ood/jupyterlab/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /modules/apps/ood/jupyterlab/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /home/pgeorge_umass_edu/.local/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/pgeorge_umass_edu/.local/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /modules/apps/ood/jupyterlab/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import os
datasets = ['similarity', 'selfparaphrase', 'paraphrase', 'negation']
experiments = [
    '20230613_234743_agg-final-01-biascont-aggall',
    '20230614_034855_agg-final-02-biascont-aggsum',
    '20230614_040557_agg-final-03-biasnone-aggall',
    '20230614_042903_agg-final-04-biasnone-aggsum',
    '20230614_060759_agg-final-05-biasent-aggall'
]

cols = ['data_type', 'mean(ds)', 'std_dev(ds)', 'corr(ds)', 'rank_corr(ds)',
       'mean(bs)', 'std_dev(bs)', 'corr(bs)', 'rank_corr(bs)',
       'mean(nli_contrast_ent)', 'std_dev(nli_contrast_ent)',
       'corr(nli_contrast_ent)', 'rank_corr(nli_contrast_ent)',
       'mean(nli_contrast_neut)', 'std_dev(nli_contrast_neut)',
       'corr(nli_contrast_neut)', 'rank_corr(nli_contrast_neut)',
       'mean(nli_contrast_cont)', 'std_dev(nli_contrast_cont)',
       'corr(nli_contrast_cont)', 'rank_corr(nli_contrast_cont)',
       'mean(nli_contrast_agg)', 'std_dev(nli_contrast_agg)',
       'corr(nli_contrast_agg)', 'rank_corr(nli_contrast_agg)']
keep_cols = [
    'data_type', 
    'mean(ds)',
    'rank_corr(ds)',
    'mean(bs)',
    'rank_corr(bs)',
    'mean(nli_contrast_ent)',
    'rank_corr(nli_contrast_ent)',
    'mean(nli_contrast_neut)',
    'rank_corr(nli_contrast_neut)',
    'mean(nli_contrast_cont)',
    'rank_corr(nli_contrast_cont)',
    'mean(nli_contrast_agg)',
    'rank_corr(nli_contrast_agg)'
]
drop_cols = [col for col in cols if col not in keep_cols]

experiment_frames = []
for experiment in experiments:
    dataset_frames = []
    first = True
    for dataset in datasets:
        filename = f"ref_experiment_{dataset}_summary.csv"
        filepath = os.path.join('/work/pi_adrozdov_umass_edu/pgeorge_umass_edu/696ds_project1/data/results/', experiment, filename)
        dataset_df = pd.read_csv(filepath)
        if not first:
            dataset_df = dataset_df.drop(index=0)
        dataset_df = dataset_df.drop(columns=drop_cols)
        dataset_frames.append(dataset_df)
        first = False
        # display(dataset_df)
    
    experiment_df = pd.concat(dataset_frames)
    experiment_df['experiment_name'] = experiment
    experiment_frames.append(experiment_df)
    display(experiment_df)

master_df = pd.concat(experiment_frames)
display(master_df)
# display(df.columns)
master_df.to_csv("Aggregated_Summaries.csv", index=False)
# Out:
#         data_type   mean(ds)  rank_corr(ds)   mean(bs)  rank_corr(bs)  \
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
#
#    mean(nli_contrast_ent)  rank_corr(nli_contrast_ent)  \
# 0               11.027345                     1.000000
# 1               23.317361                     0.297937
# 1               36.565934                     0.340017
# 1               12.394343                     0.734431
# 1                0.122549                    -0.132857
#
#    mean(nli_contrast_neut)  rank_corr(nli_contrast_neut)  \
# 0                28.513727                      1.000000
# 1                 6.853021                      0.051152
# 1                 0.485670                     -0.025982
# 1                28.011221                      0.661235
# 1                 0.000000                           NaN
#
#    mean(nli_contrast_cont)  rank_corr(nli_contrast_cont)  \
# 0                60.458928                      1.000000
# 1                69.829619                      0.262136
# 1                62.948395                      0.400691
# 1                59.594436                      0.731254
# 1                99.877451                      0.045227
#
#    mean(nli_contrast_agg)  rank_corr(nli_contrast_agg)  \
# 0               88.972655                     1.000000
# 1               76.682639                     0.297937
# 1               63.434066                     0.340017
# 1               87.605657                     0.734431
# 1               99.877451                    -0.132857
#
#                                 experiment_name
# 0  20230613_234743_agg-final-01-biascont-aggall
# 1  20230613_234743_agg-final-01-biascont-aggall
# 1  20230613_234743_agg-final-01-biascont-aggall
# 1  20230613_234743_agg-final-01-biascont-aggall
# 1  20230613_234743_agg-final-01-biascont-aggall
#         data_type   mean(ds)  rank_corr(ds)   mean(bs)  rank_corr(bs)  \
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
#
#    mean(nli_contrast_ent)  rank_corr(nli_contrast_ent)  \
# 0               10.055185                     1.000000
# 1               27.897001                     0.351007
# 1               45.582806                     0.450983
# 1               10.632375                     0.685117
# 1                0.122549                    -0.139880
#
#    mean(nli_contrast_neut)  rank_corr(nli_contrast_neut)  \
# 0                54.275060                      1.000000
# 1                19.170387                      0.041565
# 1                 1.615468                      0.014860
# 1                53.409556                      0.714998
# 1                 0.000000                           NaN
#
#    mean(nli_contrast_cont)  rank_corr(nli_contrast_cont)  \
# 0                35.669755                      1.000000
# 1                52.932612                      0.320192
# 1                52.801727                      0.385844
# 1                35.958068                      0.780347
# 1                99.877451                     -0.074768
#
#    mean(nli_contrast_agg)  rank_corr(nli_contrast_agg)  \
# 0               89.944815                     1.000000
# 1               72.102999                     0.351007
# 1               54.417194                     0.450983
# 1               89.367625                     0.685117
# 1               99.877451                    -0.139880
#
#                                 experiment_name
# 0  20230614_034855_agg-final-02-biascont-aggsum
# 1  20230614_034855_agg-final-02-biascont-aggsum
# 1  20230614_034855_agg-final-02-biascont-aggsum
# 1  20230614_034855_agg-final-02-biascont-aggsum
# 1  20230614_034855_agg-final-02-biascont-aggsum
#         data_type   mean(ds)  rank_corr(ds)   mean(bs)  rank_corr(bs)  \
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
#
#    mean(nli_contrast_ent)  rank_corr(nli_contrast_ent)  \
# 0               13.986200                     1.000000
# 1               39.985821                     0.307625
# 1               62.232707                     0.385325
# 1               15.653801                     0.668843
# 1                0.674852                    -0.124752
#
#    mean(nli_contrast_neut)  rank_corr(nli_contrast_neut)  \
# 0                28.513727                      1.000000
# 1                 6.853021                      0.051152
# 1                 0.485670                     -0.025982
# 1                28.011221                      0.661235
# 1                 0.000000                           NaN
#
#    mean(nli_contrast_cont)  rank_corr(nli_contrast_cont)  \
# 0                57.500073                      1.000000
# 1                53.161159                      0.327933
# 1                37.281623                      0.460996
# 1                56.334979                      0.719107
# 1                99.325148                     -0.146110
#
#    mean(nli_contrast_agg)  rank_corr(nli_contrast_agg)  \
# 0               86.013800                     1.000000
# 1               60.014179                     0.307625
# 1               37.767293                     0.385325
# 1               84.346199                     0.668843
# 1               99.325148                    -0.124752
#
#                                 experiment_name
# 0  20230614_040557_agg-final-03-biasnone-aggall
# 1  20230614_040557_agg-final-03-biasnone-aggall
# 1  20230614_040557_agg-final-03-biasnone-aggall
# 1  20230614_040557_agg-final-03-biasnone-aggall
# 1  20230614_040557_agg-final-03-biasnone-aggall
#         data_type   mean(ds)  rank_corr(ds)   mean(bs)  rank_corr(bs)  \
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
#
#    mean(nli_contrast_ent)  rank_corr(nli_contrast_ent)  \
# 0               11.038937                     1.000000
# 1               32.963657                     0.301955
# 1               55.293586                     0.472484
# 1               11.472339                     0.677106
# 1                0.674852                    -0.072811
#
#    mean(nli_contrast_neut)  rank_corr(nli_contrast_neut)  \
# 0                54.275060                      1.000000
# 1                19.170387                      0.041565
# 1                 1.615468                      0.014860
# 1                53.409556                      0.714998
# 1                 0.000000                           NaN
#
#    mean(nli_contrast_cont)  rank_corr(nli_contrast_cont)  \
# 0                34.686004                      1.000000
# 1                47.865957                      0.330893
# 1                43.090947                      0.402031
# 1                35.118105                      0.767347
# 1                99.325148                     -0.196401
#
#    mean(nli_contrast_agg)  rank_corr(nli_contrast_agg)  \
# 0               88.961063                     1.000000
# 1               67.036343                     0.301955
# 1               44.706414                     0.472484
# 1               88.527661                     0.677106
# 1               99.325148                    -0.072811
#
#                                 experiment_name
# 0  20230614_042903_agg-final-04-biasnone-aggsum
# 1  20230614_042903_agg-final-04-biasnone-aggsum
# 1  20230614_042903_agg-final-04-biasnone-aggsum
# 1  20230614_042903_agg-final-04-biasnone-aggsum
# 1  20230614_042903_agg-final-04-biasnone-aggsum
#         data_type   mean(ds)  rank_corr(ds)   mean(bs)  rank_corr(bs)  \
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
#
#    mean(nli_contrast_ent)  rank_corr(nli_contrast_ent)  \
# 0               27.284764                     1.000000
# 1               75.943903                    -0.134824
# 1               98.882447                    -0.200167
# 1               29.940950                     0.551250
# 1                8.836107                     0.084254
#
#    mean(nli_contrast_neut)  rank_corr(nli_contrast_neut)  \
# 0                28.513727                      1.000000
# 1                 6.853021                      0.051152
# 1                 0.485670                     -0.025982
# 1                28.011221                      0.661235
# 1                 0.000000                           NaN
#
#    mean(nli_contrast_cont)  rank_corr(nli_contrast_cont)  \
# 0                44.201509                      1.000000
# 1                17.203077                      0.184947
# 1                 0.631883                      0.012555
# 1                42.047829                      0.635370
# 1                91.163893                     -0.097502
#
#    mean(nli_contrast_agg)  rank_corr(nli_contrast_agg)  \
# 0               72.715236                     1.000000
# 1               24.056097                    -0.134824
# 1                1.117553                    -0.200167
# 1               70.059050                     0.551250
# 1               91.163893                     0.084254
#
#                                experiment_name
# 0  20230614_060759_agg-final-05-biasent-aggall
# 1  20230614_060759_agg-final-05-biasent-aggall
# 1  20230614_060759_agg-final-05-biasent-aggall
# 1  20230614_060759_agg-final-05-biasent-aggall
# 1  20230614_060759_agg-final-05-biasent-aggall
#         data_type   mean(ds)  rank_corr(ds)   mean(bs)  rank_corr(bs)  \
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
# 0            base  69.801675       1.000000  79.607242       1.000000
# 1      similarity  55.383484       0.316723  63.852530       0.231710
# 1  selfparaphrase  45.414541       0.240922  34.950076      -0.069873
# 1      paraphrase  71.470025       0.519686  81.337894       0.731016
# 1        negation  25.664613       0.124967  34.970485      -0.137073
#
#    mean(nli_contrast_ent)  rank_corr(nli_contrast_ent)  \
# 0               11.027345                     1.000000
# 1               23.317361                     0.297937
# 1               36.565934                     0.340017
# 1               12.394343                     0.734431
# 1                0.122549                    -0.132857
# 0               10.055185                     1.000000
# 1               27.897001                     0.351007
# 1               45.582806                     0.450983
# 1               10.632375                     0.685117
# 1                0.122549                    -0.139880
# 0               13.986200                     1.000000
# 1               39.985821                     0.307625
# 1               62.232707                     0.385325
# 1               15.653801                     0.668843
# 1                0.674852                    -0.124752
# 0               11.038937                     1.000000
# 1               32.963657                     0.301955
# 1               55.293586                     0.472484
# 1               11.472339                     0.677106
# 1                0.674852                    -0.072811
# 0               27.284764                     1.000000
# 1               75.943903                    -0.134824
# 1               98.882447                    -0.200167
# 1               29.940950                     0.551250
# 1                8.836107                     0.084254
#
#    mean(nli_contrast_neut)  rank_corr(nli_contrast_neut)  \
# 0                28.513727                      1.000000
# 1                 6.853021                      0.051152
# 1                 0.485670                     -0.025982
# 1                28.011221                      0.661235
# 1                 0.000000                           NaN
# 0                54.275060                      1.000000
# 1                19.170387                      0.041565
# 1                 1.615468                      0.014860
# 1                53.409556                      0.714998
# 1                 0.000000                           NaN
# 0                28.513727                      1.000000
# 1                 6.853021                      0.051152
# 1                 0.485670                     -0.025982
# 1                28.011221                      0.661235
# 1                 0.000000                           NaN
# 0                54.275060                      1.000000
# 1                19.170387                      0.041565
# 1                 1.615468                      0.014860
# 1                53.409556                      0.714998
# 1                 0.000000                           NaN
# 0                28.513727                      1.000000
# 1                 6.853021                      0.051152
# 1                 0.485670                     -0.025982
# 1                28.011221                      0.661235
# 1                 0.000000                           NaN
#
#    mean(nli_contrast_cont)  rank_corr(nli_contrast_cont)  \
# 0                60.458928                      1.000000
# 1                69.829619                      0.262136
# 1                62.948395                      0.400691
# 1                59.594436                      0.731254
# 1                99.877451                      0.045227
# 0                35.669755                      1.000000
# 1                52.932612                      0.320192
# 1                52.801727                      0.385844
# 1                35.958068                      0.780347
# 1                99.877451                     -0.074768
# 0                57.500073                      1.000000
# 1                53.161159                      0.327933
# 1                37.281623                      0.460996
# 1                56.334979                      0.719107
# 1                99.325148                     -0.146110
# 0                34.686004                      1.000000
# 1                47.865957                      0.330893
# 1                43.090947                      0.402031
# 1                35.118105                      0.767347
# 1                99.325148                     -0.196401
# 0                44.201509                      1.000000
# 1                17.203077                      0.184947
# 1                 0.631883                      0.012555
# 1                42.047829                      0.635370
# 1                91.163893                     -0.097502
#
#    mean(nli_contrast_agg)  rank_corr(nli_contrast_agg)  \
# 0               88.972655                     1.000000
# 1               76.682639                     0.297937
# 1               63.434066                     0.340017
# 1               87.605657                     0.734431
# 1               99.877451                    -0.132857
# 0               89.944815                     1.000000
# 1               72.102999                     0.351007
# 1               54.417194                     0.450983
# 1               89.367625                     0.685117
# 1               99.877451                    -0.139880
# 0               86.013800                     1.000000
# 1               60.014179                     0.307625
# 1               37.767293                     0.385325
# 1               84.346199                     0.668843
# 1               99.325148                    -0.124752
# 0               88.961063                     1.000000
# 1               67.036343                     0.301955
# 1               44.706414                     0.472484
# 1               88.527661                     0.677106
# 1               99.325148                    -0.072811
# 0               72.715236                     1.000000
# 1               24.056097                    -0.134824
# 1                1.117553                    -0.200167
# 1               70.059050                     0.551250
# 1               91.163893                     0.084254
#
#                                 experiment_name
# 0  20230613_234743_agg-final-01-biascont-aggall
# 1  20230613_234743_agg-final-01-biascont-aggall
# 1  20230613_234743_agg-final-01-biascont-aggall
# 1  20230613_234743_agg-final-01-biascont-aggall
# 1  20230613_234743_agg-final-01-biascont-aggall
# 0  20230614_034855_agg-final-02-biascont-aggsum
# 1  20230614_034855_agg-final-02-biascont-aggsum
# 1  20230614_034855_agg-final-02-biascont-aggsum
# 1  20230614_034855_agg-final-02-biascont-aggsum
# 1  20230614_034855_agg-final-02-biascont-aggsum
# 0  20230614_040557_agg-final-03-biasnone-aggall
# 1  20230614_040557_agg-final-03-biasnone-aggall
# 1  20230614_040557_agg-final-03-biasnone-aggall
# 1  20230614_040557_agg-final-03-biasnone-aggall
# 1  20230614_040557_agg-final-03-biasnone-aggall
# 0  20230614_042903_agg-final-04-biasnone-aggsum
# 1  20230614_042903_agg-final-04-biasnone-aggsum
# 1  20230614_042903_agg-final-04-biasnone-aggsum
# 1  20230614_042903_agg-final-04-biasnone-aggsum
# 1  20230614_042903_agg-final-04-biasnone-aggsum
# 0   20230614_060759_agg-final-05-biasent-aggall
# 1   20230614_060759_agg-final-05-biasent-aggall
# 1   20230614_060759_agg-final-05-biasent-aggall
# 1   20230614_060759_agg-final-05-biasent-aggall
# 1   20230614_060759_agg-final-05-biasent-aggall
