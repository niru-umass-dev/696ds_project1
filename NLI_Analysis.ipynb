# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
cont_df = pd.read_csv("contrast.csv").fillna('')
fact_pop_df = pd.read_csv("factuality_popular.csv").fillna('')

# %%
cont_df.head(20)
# Out:
#                                             SentenceA  \
# 0   The hotel has conference rooms available to re...
# 1   The hotel has conference rooms available to re...
# 2   The hotel has conference rooms available to re...
# 3   The hotel has conference rooms available to re...
# 4   The hotel has conference rooms available to re...
# 5   The hotel has conference rooms available to re...
# 6   The location of this hotel makes it easy to ac...
# 7   The location of this hotel makes it easy to ac...
# 8   The location of this hotel makes it easy to ac...
# 9   The location of this hotel makes it easy to ac...
# 10  The location of this hotel makes it easy to ac...
# 11  The location of this hotel makes it easy to ac...
# 12      The rooms are a good size and well decorated.
# 13      The rooms are a good size and well decorated.
# 14      The rooms are a good size and well decorated.
# 15      The rooms are a good size and well decorated.
# 16      The rooms are a good size and well decorated.
# 17      The rooms are a good size and well decorated.
# 18  The bathroom in the hotel was large and with a...
# 19  The bathroom in the hotel was large and with a...
#
#                                             SentenceB  Sample A_B_neut  \
# 0   The hotel is especially memorable during a win...      20  neutral
# 1   The room was okay but on the small side includ...      20  neutral
# 2   After upgrading rooms to a suite this was abso...      20  neutral
# 3   Whilst the breakfast and dinners are both quit...      20  neutral
# 4   But a coffee maker and coffee was not free of ...      20  neutral
# 5   Whilst the toiletries were really great there ...      20  neutral
# 6   The hotel is especially memorable during a win...      20  neutral
# 7   The room was okay but on the small side includ...      20  neutral
# 8   After upgrading rooms to a suite this was abso...      20  neutral
# 9   Whilst the breakfast and dinners are both quit...      20  neutral
# 10  But a coffee maker and coffee was not free of ...      20  neutral
# 11  Whilst the toiletries were really great there ...      20  neutral
# 12  The hotel is especially memorable during a win...      20  neutral
# 13  The room was okay but on the small side includ...      20  neutral
# 14  After upgrading rooms to a suite this was abso...      20  neutral
# 15  Whilst the breakfast and dinners are both quit...      20  neutral
# 16  But a coffee maker and coffee was not free of ...      20  neutral
# 17  Whilst the toiletries were really great there ...      20  neutral
# 18  The hotel is especially memorable during a win...      20  neutral
# 19  The room was okay but on the small side includ...      20  neutral
#
#    A_B_cont A_B_ent B_A_neut       B_A_cont     B_A_ent Type
# 0                    neutral                             ref
# 1                    neutral                             ref
# 2                    neutral                             ref
# 3                    neutral                             ref
# 4                    neutral                             ref
# 5                    neutral                             ref
# 6                    neutral                             ref
# 7                    neutral                             ref
# 8                    neutral                             ref
# 9                    neutral                             ref
# 10                   neutral                             ref
# 11                   neutral                             ref
# 12                   neutral                             ref
# 13                            contradiction              ref
# 14                                           entailment  ref
# 15                   neutral                             ref
# 16                   neutral                             ref
# 17                   neutral                             ref
# 18                   neutral                             ref
# 19                            contradiction              ref

# %%
fact_pop_df.head(20)
# Out:
#                                             SentenceA  \
# 0   Our company has rented conference rooms and he...
# 1   Our company has rented conference rooms and he...
# 2   Our company has rented conference rooms and he...
# 3   Our company has rented conference rooms and he...
# 4   Our company has rented conference rooms and he...
# 5   Our company has rented conference rooms and he...
# 6   Our company has rented conference rooms and he...
# 7   There was always someone to greet and help wit...
# 8   There was always someone to greet and help wit...
# 9   There was always someone to greet and help wit...
# 10  There was always someone to greet and help wit...
# 11  There was always someone to greet and help wit...
# 12  There was always someone to greet and help wit...
# 13  There was always someone to greet and help wit...
# 14  More importantly, technical service was effici...
# 15  More importantly, technical service was effici...
# 16  More importantly, technical service was effici...
# 17  More importantly, technical service was effici...
# 18  More importantly, technical service was effici...
# 19  More importantly, technical service was effici...
#
#                                             SentenceB  Sample A_B_neut  \
# 0   The hotel has conference rooms available to re...      20
# 1   The location of this hotel makes it easy to ac...      20  neutral
# 2       The rooms are a good size and well decorated.      20  neutral
# 3   The bathroom in the hotel was large and with a...      20  neutral
# 4   Small touches like a chocolate on the pillow a...      20  neutral
# 5            The hotel has a roof terrace for drinks.      20  neutral
# 6   Unfortunately the hotel is missing the availab...      20  neutral
# 7   The hotel has conference rooms available to re...      20  neutral
# 8   The location of this hotel makes it easy to ac...      20  neutral
# 9       The rooms are a good size and well decorated.      20  neutral
# 10  The bathroom in the hotel was large and with a...      20  neutral
# 11  Small touches like a chocolate on the pillow a...      20  neutral
# 12           The hotel has a roof terrace for drinks.      20  neutral
# 13  Unfortunately the hotel is missing the availab...      20
# 14  The hotel has conference rooms available to re...      20  neutral
# 15  The location of this hotel makes it easy to ac...      20  neutral
# 16      The rooms are a good size and well decorated.      20  neutral
# 17  The bathroom in the hotel was large and with a...      20  neutral
# 18  Small touches like a chocolate on the pillow a...      20  neutral
# 19           The hotel has a roof terrace for drinks.      20  neutral
#
#          A_B_cont     A_B_ent  Source_Rev_num Entity Type
# 0                  entailment               0      a  ref
# 1                                           0      a  ref
# 2                                           0      a  ref
# 3                                           0      a  ref
# 4                                           0      a  ref
# 5                                           0      a  ref
# 6                                           0      a  ref
# 7                                           0      a  ref
# 8                                           0      a  ref
# 9                                           0      a  ref
# 10                                          0      a  ref
# 11                                          0      a  ref
# 12                                          0      a  ref
# 13  contradiction                           0      a  ref
# 14                                          0      a  ref
# 15                                          0      a  ref
# 16                                          0      a  ref
# 17                                          0      a  ref
# 18                                          0      a  ref
# 19                                          0      a  ref
